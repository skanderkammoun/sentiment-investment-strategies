# %% [markdown]
# # 📊 Étape 4 : Analyse Exploratoire des Données (EDA) Croisée
#
# Ce notebook est dédié à la fusion et à l'analyse des relations entre nos données textuelles (Sentiment FinBERT) et nos données financières (StockChange).
#
# ### 🎯 Objectifs du Cahier des Charges :
# 1. **La Grande Fusion :** Aligner les indicateurs de sentiment avec les rendements boursiers.
# 2. **Étude statistique :** Moyenne, variance, corrélation.
# 3. **Visualisation :** Évolution des prix vs sentiment.
# 4. **Analyse des relations :**
#    - Corrélation sentiment – rendement.
#    - Détection de décalages temporels (Lag effect).

# %% [markdown]
# ## Importation

# %%
import pandas as pd

# %%
df_financier=pd.read_csv(r"C:\Users\semy4\OneDrive\Bureau\Fintech_project\data\processed\DONNEES_FINANCIERES_PROPRES.csv")

# %%
df_financier
# Out:
#             Date Ticker       Close        High         Low        Open  \
# 0     2020-01-02   AAPL   72.333885   72.394093   71.091191   71.344062
# 1     2020-01-03   AAPL   71.630661   72.389280   71.406689   71.563228
# 2     2020-01-06   AAPL   72.201408   72.239942   70.503546   70.754014
# 3     2020-01-07   AAPL   71.861847   72.466330   71.642689   72.211049
# 4     2020-01-08   AAPL   73.017845   73.318885   71.565629   71.565629
# ...          ...    ...         ...         ...         ...         ...
# 3015  2022-12-22   TSLA  125.349998  136.630005  122.260002  136.000000
# 3016  2022-12-23   TSLA  123.150002  128.619995  121.019997  126.370003
# 3017  2022-12-27   TSLA  109.099998  119.669998  108.760002  117.500000
# 3018  2022-12-28   TSLA  112.709999  116.269997  108.239998  110.349998
# 3019  2022-12-29   TSLA  121.820000  123.570000  117.500000  120.389999
#
#          Volume  StockChange_%  StockChange_Lendemain_%
# ...
